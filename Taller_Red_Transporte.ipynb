# %% [markdown]
# <a href="https://colab.research.google.com/github/nestorm94/SIS_COMP_2023_1/blob/main/Taller_Red_Transporte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div>
# <img src="https://res-5.cloudinary.com/crunchbase-production/image/upload/c_lpad,h_256,w_256,f_auto,q_auto:eco/v1455514364/pim02bzqvgz0hibsra41.png" align="right"><br><br><FONT FACE="times new roman" SIZE=5>
# <b></b>
# <br>
# <i><b>Docente:</b></i> Joaquin Fernando Sanchez Cifuentes
# <br>
# <i><b>Asignatura:</b></i> Sistemas Complejos
# <br>
# <i><b>Estudiante:</b></i> Nestor Morales.
# <br>
# <i><b>Estudiante:</b></i>Maria paula  Parra
# <br>
# <i><b>Estudiante:</b></i> Raul Perez
# <br>
# <i><b>Estudiante:</b></i> Ruben Camargo
# <br>
# <i><b>Tema:</b></i> Taller Redes Robustas
# <br>
# <br>
# 17/05/2023
# <br>
# </FONT>
# </div>

# %%
# !pip install networkx
# !pip install odfpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting odfpy
#   Downloading odfpy-1.4.1.tar.gz (717 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 717.0/717.0 kB 23.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from odfpy) (0.7.1)
# Building wheels for collected packages: odfpy
#   Building wheel for odfpy (setup.py) ... done
#   Created wheel for odfpy: filename=odfpy-1.4.1-py2.py3-none-any.whl size=160672 sha256=9bf4bc989115efd9e87810b83f8b142905c1d758298eb4e0ad1cd8363e736255
#   Stored in directory: /root/.cache/pip/wheels/c8/2e/95/90d94fe33903786937f3b8c33dd88807f792359c6424b40469
# Successfully built odfpy
# Installing collected packages: odfpy
# Successfully installed odfpy-1.4.1

# %%
import networkx as nx
# %matplotlib inline
import pandas as pd

# %% [markdown]
# # **Primera ciudad: Chicago**

# %%
dfChicago = pd.read_excel('ChicagoSketch_net1.xlsx', sheet_name='ChicagoSketch_net')
dfChicago.head()
# Out:
#    init_node  term_node  capacity   length  free_flow_time     b  power  \
# 0          1        547     49500  0.86267             0.0  0.15      4
# 1          2        548     49500  0.86267             0.0  0.15      4
# 2          3        549     49500  0.86267             0.0  0.15      4
# 3          4        550     49500  0.86267             0.0  0.15      4
# 4          5        551     49500  0.86267             0.0  0.15      4
#
#    speed  toll  link_type  ;
# 0      0     0          3  ;
# 1      0     0          3  ;
# 2      0     0          3  ;
# 3      0     0          3  ;
# 4      0     0          3  ;

# %%
list_Int_nodeChicago = dfChicago['init_node'].tolist()  # lista de nodos iniciales
list_Ter_nodeChicago = dfChicago['term_node'].tolist()  # lista de nodos finales
list_weightChicago = dfChicago['length'].tolist()  # lista de pesos de los arcos
# los pesos sirven para calcular el coste de los arcos, es decir, el coste de pasar de un nodo a otro, para poder calcular el coste total de una ruta

list_edgeChicago = []  # lista de arcos
for i in range(len(list_Int_nodeChicago)):  # recorremos la lista de nodos iniciales
    varChicago = (list_Int_nodeChicago[i], list_Ter_nodeChicago[i])  # creamos una tupla con los nodos iniciales y finales
    list_edgeChicago.append(varChicago)  # añadimos la tupla a la lista de arcos

GChicago = nx.DiGraph()  # creamos el grafo
GChicago.add_nodes_from(list_Int_nodeChicago)  # añadimos los nodos iniciales al grafo
for i in range(len(list_weightChicago)):  # recorremos la lista de pesos de los arcos
    GChicago.add_edges_from(list_edgeChicago, weight=list_weightChicago[i])  # añadimos los arcos al grafo

nx.draw(GChicago, with_labels=True)  # dibujamos el grafo

# %%
# Calcular la centralidad de intermediación de cada nodo
betweenness_dict = nx.betweenness_centrality(GChicago)

# Ordenar los nodos por su centralidad de intermediación
sorted_nodes = sorted(betweenness_dict.items(), key=lambda x: x[1], reverse=True)

# Mostrar los 10 nodos con mayor centralidad de intermediación
for node in sorted_nodes[:10]:
    print("Nodo:", node[0], "- Centralidad de intermediación:", node[1])
# Out:
# Nodo: 913 - Centralidad de intermediación: 0.19054935914026316
# Nodo: 864 - Centralidad de intermediación: 0.1771251754898003
# Nodo: 584 - Centralidad de intermediación: 0.16817060702589198
# Nodo: 571 - Centralidad de intermediación: 0.15167531464004474
# Nodo: 631 - Centralidad de intermediación: 0.13614678985155176
# Nodo: 871 - Centralidad de intermediación: 0.1286531703788065
# Nodo: 874 - Centralidad de intermediación: 0.1254927379542176
# Nodo: 557 - Centralidad de intermediación: 0.12361802120323756
# Nodo: 875 - Centralidad de intermediación: 0.11439864198021964
# Nodo: 868 - Centralidad de intermediación: 0.10834629198908964

# %%
import matplotlib.pyplot as plt

# Calcular la distribución de grado de la red
degree_sequence = [d for n, d in GChicago.degree()]
degree_count = nx.degree_histogram(GChicago)

# Graficar la distribución de grado
plt.plot(degree_count, 'b-', marker='o')
plt.title("Distribución de grado")
plt.xlabel("Grado")
plt.ylabel("Número de nodos")
plt.show()

# %%
# Crear el grafo
list_Int_nodeChicago = dfChicago['init_node'][0:10].tolist() # Lista de nodos iniciales
list_Ter_nodeChicago = dfChicago['term_node'][0:10].tolist() # Lista de nodos finales
list_weightChicago = dfChicago['length'][0:10].tolist() # Lista de pesos de los arcos

list_edgeChicago = [] # Lista de arcos
for i in range(len(list_Int_nodeChicago)): # Recorremos la lista de nodos iniciales
    varChicago = (list_Int_nodeChicago[i], list_Ter_nodeChicago[i]) # Creamos una tupla con los nodos iniciales y finales
    list_edgeChicago.append(varChicago) # Añadimos la tupla a la lista de arcos

GChicago = nx.DiGraph() # Creamos el grafo
GChicago.add_nodes_from(list_Int_nodeChicago) # Añadimos los nodos iniciales al grafo
for i in range(len(list_weightChicago)): # Recorremos la lista de pesos de los arcos
    GChicago.add_edges_from(list_edgeChicago, weight=list_weightChicago[i]) # Añadimos los arcos al grafo

nx.draw(GChicago, with_labels=True) #dibujamos el grafo

# %%
# Método para crear el grafo
posChicago = nx.spring_layout(GChicago)  # Posicionamiento del grafo
weight_labelsChicago = nx.get_edge_attributes(GChicago, 'weight')  # Obtenemos los pesos de los arcos para poder mostrarlos y calcular el coste total de una ruta
nx.draw_networkx(GChicago, posChicago, with_labels=True, font_weight='bold')  # Dibujamos el grafo para visualizarlo
labelsChicago = nx.get_edge_attributes(GChicago, 'weight')  # Obtenemos los pesos de los arcos para mostrarlos en el grafo dibujado
nx.draw_networkx_edge_labels(GChicago, posChicago, edge_labels=labelsChicago)  # Dibujamos los pesos de los arcos en el grafo dibujado
nx.draw_networkx_edge_labels(GChicago, posChicago, edge_labels=weight_labelsChicago)  # Dibujamos los pesos de los arcos en el grafo dibujado# Mostramos el grafo dibujado
# Out:
# {(1, 547): Text(0.5535076353540487, 0.44078231781019883, '0.86267'),
#  (2, 548): Text(0.9267004417431879, -0.2836339111660996, '0.86267'),
#  (3, 549): Text(-0.7536666741893332, -0.02512573467073216, '0.86267'),
#  (4, 550): Text(0.3274813794758843, 0.9478544813696261, '0.86267'),
#  (5, 551): Text(0.6308120778294262, -0.5020425801603526, '0.86267'),
#  (6, 552): Text(-0.6546905502486775, 0.35328095361678014, '0.86267'),
#  (7, 553): Text(0.2986145895195469, -0.7659323358424199, '0.86267'),
#  (8, 554): Text(-0.3694766920490989, 0.8558864227375838, '0.86267'),
#  (9, 555): Text(-0.5546894964310956, -0.31864707090138483, '0.86267'),
#  (10, 556): Text(-0.4045927110038887, -0.7024225427931998, '0.86267')}

# %% [markdown]
# # **Segunda ciudad: Berlin Center**

# %%
dfBerlin = pd.read_excel('berlin-center_net.xlsx', sheet_name='berlin-center_net')
dfBerlin.head()
# Out:
#    init_node  term_node          capacity  length  free_flow_time    b  \
# 0          1      11000  9999990000000000     0.0             0.0  0.0
# 1          1      11007  9999990000000000     0.0             0.0  0.0
# 2          1      11704  9999990000000000     0.0             0.0  0.0
# 3          1      11708  9999990000000000     0.0             0.0  0.0
# 4          1      11717  9999990000000000     0.0             0.0  0.0
#
#      power  speed  toll  link_type   ;
# 0  4000000    0.0   0.0          0  ;
# 1  4000000    0.0   0.0          0  ;
# 2  4000000    0.0   0.0          0  ;
# 3  4000000    0.0   0.0          0  ;
# 4  4000000    0.0   0.0          0  ;

# %%
#metodo para crear el grafo
list_Int_nodeBerlin = dfBerlin['init_node'].tolist() #lista de nodos iniciales 
list_Ter_nodeBerlin = dfBerlin['term_node'].tolist() #lista de nodos finales
list_weigthBerlin=dfBerlin['length'].tolist() #lista de pesos de los arcos 
#los pesos sirven para calcular el coste de los arcos osea el coste de pasar de un nodo a otro para asi poder calcular el coste total de una ruta

list_edgeBerlin=[] #lista de arcos 
for i in range(len(list_Int_nodeBerlin)): #recorremos la lista de nodos iniciales
  varBerlin=(list_Int_nodeBerlin[i],list_Ter_nodeBerlin[i]) #creamos una tupla con los nodos iniciales y finales
  list_edgeBerlin.append(varBerlin) #añadimos la tupla a la lista de arcos 


GBerlin = nx.DiGraph() #creamos el grafo 
GBerlin.add_nodes_from(list_Int_nodeBerlin) #añadimos los nodos iniciales al grafo
for i in range(len(list_weigthBerlin)): #recorremos la lista de pesos de los arcos 
  GBerlin.add_edges_from(list_edgeBerlin, weigth=list_weigthBerlin[i]) #añadimos los arcos al grafo 

nx.draw(GBerlin, with_labels=True) #dibujamos el grafo

# %%
# Calcular la centralidad de intermediación de cada nodo
betweenness_dict = nx.betweenness_centrality(GBerlin)

# Ordenar los nodos por su centralidad de intermediación
sorted_nodes = sorted(betweenness_dict.items(), key=lambda x: x[1], reverse=True)

# Mostrar los 10 nodos con mayor centralidad de intermediación
for node in sorted_nodes[:10]:
    print("Nodo:", node[0], "- Centralidad de intermediación:", node[1])
# Out:
# Nodo: 8266 - Centralidad de intermediación: 0.10159733145384219
# Nodo: 11007 - Centralidad de intermediación: 0.09591352571727607
# Nodo: 11134 - Centralidad de intermediación: 0.08692684319525205
# Nodo: 358 - Centralidad de intermediación: 0.08632778368774377
# Nodo: 3536 - Centralidad de intermediación: 0.08435375424075425
# Nodo: 10768 - Centralidad de intermediación: 0.08277297442733839
# Nodo: 10771 - Centralidad de intermediación: 0.08191412572693688
# Nodo: 11144 - Centralidad de intermediación: 0.08132720731501551
# Nodo: 11139 - Centralidad de intermediación: 0.08069638667295487
# Nodo: 11136 - Centralidad de intermediación: 0.08051511486163243
# Nodo: 10817 - Centralidad de intermediación: 0.07980687968557958
# Nodo: 10819 - Centralidad de intermediación: 0.07980676690412901
# Nodo: 10159 - Centralidad de intermediación: 0.07959311778657789
# Nodo: 10158 - Centralidad de intermediación: 0.079524398928444
# Nodo: 12961 - Centralidad de intermediación: 0.0793018483783486
# Nodo: 12963 - Centralidad de intermediación: 0.07930173559689802
# Nodo: 11847 - Centralidad de intermediación: 0.07915616763756222
# Nodo: 10818 - Centralidad de intermediación: 0.07724893783206267
# Nodo: 3264 - Centralidad de intermediación: 0.07703598027877931
# Nodo: 11133 - Centralidad de intermediación: 0.07687136480937351
# Nodo: 12836 - Centralidad de intermediación: 0.07672860383081907
# Nodo: 12826 - Centralidad de intermediación: 0.07672849104936852
# Nodo: 12962 - Centralidad de intermediación: 0.0763322673563795
# Nodo: 10845 - Centralidad de intermediación: 0.07610576743917542
# Nodo: 10157 - Centralidad de intermediación: 0.07565626647664832
# Nodo: 10811 - Centralidad de intermediación: 0.07565615369519776
# Nodo: 3384 - Centralidad de intermediación: 0.07431656707565468
# Nodo: 3920 - Centralidad de intermediación: 0.07431645429420412
# Nodo: 1283 - Centralidad de intermediación: 0.07411938307072309
# Nodo: 3175 - Centralidad de intermediación: 0.07411927028927254
# Nodo: 10762 - Centralidad de intermediación: 0.07335744535976714
# Nodo: 3845 - Centralidad de intermediación: 0.07325647719382085
# Nodo: 10842 - Centralidad de intermediación: 0.07286372118020416
# Nodo: 3919 - Centralidad de intermediación: 0.07281626324179838
# Nodo: 3532 - Centralidad de intermediación: 0.07267624741222618
# Nodo: 12964 - Centralidad de intermediación: 0.07241195763141953
# Nodo: 3174 - Centralidad de intermediación: 0.07215919053411086
# Nodo: 10261 - Centralidad de intermediación: 0.0721590777526603
# Nodo: 10836 - Centralidad de intermediación: 0.07184873640792218
# Nodo: 10840 - Centralidad de intermediación: 0.07184862362647161
# Nodo: 3263 - Centralidad de intermediación: 0.07084769711310157
# Nodo: 10813 - Centralidad de intermediación: 0.070847584331651
# Nodo: 10816 - Centralidad de intermediación: 0.07084747155020044
# Nodo: 8923 - Centralidad de intermediación: 0.06966134770052457
# Nodo: 2920 - Centralidad de intermediación: 0.06928737611539895
# Nodo: 1284 - Centralidad de intermediación: 0.0692872633339484
# Nodo: 11140 - Centralidad de intermediación: 0.0692515755498723
# Nodo: 3253 - Centralidad de intermediación: 0.06924827499249132
# Nodo: 3178 - Centralidad de intermediación: 0.06924816221104077
# Nodo: 12845 - Centralidad de intermediación: 0.06866774406830002
# Nodo: 12895 - Centralidad de intermediación: 0.06781701040593514
# Nodo: 12173 - Centralidad de intermediación: 0.06629060689043302
# Nodo: 12897 - Centralidad de intermediación: 0.06609363236357067
# Nodo: 10258 - Centralidad de intermediación: 0.06606238256207948
# Nodo: 3159 - Centralidad de intermediación: 0.06606226978062894
# Nodo: 12969 - Centralidad de intermediación: 0.06569449889690206
# Nodo: 3160 - Centralidad de intermediación: 0.06560997409830845
# Nodo: 1596 - Centralidad de intermediación: 0.06560986131685786
# Nodo: 1597 - Centralidad de intermediación: 0.06492637928496076
# Nodo: 1472 - Centralidad de intermediación: 0.0649262665035102
# Nodo: 9108 - Centralidad de intermediación: 0.06453439303900793
# Nodo: 10111 - Centralidad de intermediación: 0.06392452596867394
# Nodo: 10833 - Centralidad de intermediación: 0.06362397433675007
# Nodo: 8919 - Centralidad de intermediación: 0.0633655913290832
# Nodo: 2827 - Centralidad de intermediación: 0.06336547854763264
# Nodo: 9993 - Centralidad de intermediación: 0.062283707624547935
# Nodo: 9997 - Centralidad de intermediación: 0.06228359484309737
# Nodo: 10100 - Centralidad de intermediación: 0.06067153654947052
# Nodo: 12896 - Centralidad de intermediación: 0.06067142376801996
# Nodo: 9996 - Centralidad de intermediación: 0.060452590652728386
# Nodo: 12898 - Centralidad de intermediación: 0.06021537766437288
# Nodo: 10118 - Centralidad de intermediación: 0.05966627097413869
# Nodo: 10115 - Centralidad de intermediación: 0.059666158192688126
# Nodo: 1767 - Centralidad de intermediación: 0.05906521361928177
# Nodo: 3254 - Centralidad de intermediación: 0.05906510083783121
# Nodo: 1046 - Centralidad de intermediación: 0.058814412267492525
# Nodo: 3180 - Centralidad de intermediación: 0.05877223757425232
# Nodo: 3176 - Centralidad de intermediación: 0.058772124792801764
# Nodo: 12892 - Centralidad de intermediación: 0.058504972713637506
# Nodo: 3088 - Centralidad de intermediación: 0.05793628461306462
# Nodo: 1762 - Centralidad de intermediación: 0.05793617183161406
# Nodo: 10102 - Centralidad de intermediación: 0.05781296153206273
# Nodo: 10885 - Centralidad de intermediación: 0.05762997027827283
# Nodo: 3212 - Centralidad de intermediación: 0.05741193488441948
# Nodo: 3216 - Centralidad de intermediación: 0.05741182210296892
# Nodo: 3215 - Centralidad de intermediación: 0.05733478643636931
# Nodo: 1394 - Centralidad de intermediación: 0.057334673654918775
# Nodo: 1393 - Centralidad de intermediación: 0.05709101012440293
# Nodo: 3173 - Centralidad de intermediación: 0.05709089734295239
# Nodo: 10884 - Centralidad de intermediación: 0.05691740362848488
# Nodo: 90 - Centralidad de intermediación: 0.05665865912842683
# Nodo: 12937 - Centralidad de intermediación: 0.05640308828436243
# Nodo: 12379 - Centralidad de intermediación: 0.05640297550291188
# Nodo: 11999 - Centralidad de intermediación: 0.05600903290497129
# Nodo: 12935 - Centralidad de intermediación: 0.05600892012352073
# Nodo: 11988 - Centralidad de intermediación: 0.0557771458865003
# Nodo: 3161 - Centralidad de intermediación: 0.05572317410399425
# Nodo: 3181 - Centralidad de intermediación: 0.05572306132254368
# Nodo: 87 - Centralidad de intermediación: 0.05539516687327174
# Nodo: 1594 - Centralidad de intermediación: 0.055363410557359
# Nodo: 3162 - Centralidad de intermediación: 0.05536329777590844
# Nodo: 11991 - Centralidad de intermediación: 0.0549730637132301
# Nodo: 9873 - Centralidad de intermediación: 0.054765486523660145
# Nodo: 10119 - Centralidad de intermediación: 0.05434568029300581
# Nodo: 12936 - Centralidad de intermediación: 0.05425746385457162
# Nodo: 10003 - Centralidad de intermediación: 0.054201725577609966
# Nodo: 9994 - Centralidad de intermediación: 0.05420161279615939
# Nodo: 3379 - Centralidad de intermediación: 0.05409290540029131
# Nodo: 10105 - Centralidad de intermediación: 0.05376759444831965
# Nodo: 9992 - Centralidad de intermediación: 0.05376748166686911
# Nodo: 8285 - Centralidad de intermediación: 0.05329512063254431
# Nodo: 12890 - Centralidad de intermediación: 0.05216353454779023
# Nodo: 12891 - Centralidad de intermediación: 0.05216342176633967
# Nodo: 12931 - Centralidad de intermediación: 0.052029350509718846
# Nodo: 10591 - Centralidad de intermediación: 0.052029237728268306
# Nodo: 1105 - Centralidad de intermediación: 0.051555938757763035
# Nodo: 1318 - Centralidad de intermediación: 0.051555825976312475
# Nodo: 10114 - Centralidad de intermediación: 0.05132913322297231
# Nodo: 10121 - Centralidad de intermediación: 0.05132902044152175
# Nodo: 12147 - Centralidad de intermediación: 0.050553351339873286
# Nodo: 12928 - Centralidad de intermediación: 0.050553238558422725
# Nodo: 2906 - Centralidad de intermediación: 0.0498894413587874
# Nodo: 2922 - Centralidad de intermediación: 0.049889328577336856
# Nodo: 10101 - Centralidad de intermediación: 0.0498451341896785
# Nodo: 2489 - Centralidad de intermediación: 0.04946127353837976
# Nodo: 1750 - Centralidad de intermediación: 0.04946116075692919
# Nodo: 1748 - Centralidad de intermediación: 0.049460822412577515
# Nodo: 3091 - Centralidad de intermediación: 0.04946070963112695
# Nodo: 10846 - Centralidad de intermediación: 0.0494239618423888
# Nodo: 2925 - Centralidad de intermediación: 0.04933880436167848
# Nodo: 2927 - Centralidad de intermediación: 0.04933869158022791
# Nodo: 3177 - Centralidad de intermediación: 0.04929902655006749
# Nodo: 3255 - Centralidad de intermediación: 0.04929891376861693
# Nodo: 2359 - Centralidad de intermediación: 0.048962972417717215
# Nodo: 2824 - Centralidad de intermediación: 0.04893774600323985
# Nodo: 2254 - Centralidad de intermediación: 0.04893763322178928
# Nodo: 3037 - Centralidad de intermediación: 0.04821645028491206
# Nodo: 9360 - Centralidad de intermediación: 0.047979327353976135
# Nodo: 1372 - Centralidad de intermediación: 0.0479050075875085
# Nodo: 12933 - Centralidad de intermediación: 0.04717026248270092
# Nodo: 12932 - Centralidad de intermediación: 0.04717014970125035
# Nodo: 12934 - Centralidad de intermediación: 0.04708571356826133
# Nodo: 12948 - Centralidad de intermediación: 0.047085600786810754
# Nodo: 8273 - Centralidad de intermediación: 0.04701207003433815
# Nodo: 8927 - Centralidad de intermediación: 0.0468318318978636
# Nodo: 66 - Centralidad de intermediación: 0.04654666267861144
# Nodo: 7555 - Centralidad de intermediación: 0.04637114156621259
# Nodo: 12905 - Centralidad de intermediación: 0.04620355515583996
# Nodo: 12900 - Centralidad de intermediación: 0.04612686449092079
# Nodo: 12956 - Centralidad de intermediación: 0.04611817900756665
# Nodo: 12957 - Centralidad de intermediación: 0.046118066226116076
# Nodo: 2125 - Centralidad de intermediación: 0.04606755025886725
# Nodo: 3221 - Centralidad de intermediación: 0.04606743747741671
# Nodo: 3220 - Centralidad de intermediación: 0.045792601365478414
# Nodo: 3213 - Centralidad de intermediación: 0.04579248858402784
# Nodo: 1 - Centralidad de intermediación: 0.045784675322668715
# Nodo: 12949 - Centralidad de intermediación: 0.04577304201705932
# Nodo: 12951 - Centralidad de intermediación: 0.045688817464817226
# Nodo: 3185 - Centralidad de intermediación: 0.04568870468336667
# Nodo: 10886 - Centralidad de intermediación: 0.04556615626874941
# Nodo: 3183 - Centralidad de intermediación: 0.0449653647761137
# Nodo: 1470 - Centralidad de intermediación: 0.04496525199466315
# Nodo: 1471 - Centralidad de intermediación: 0.04482446124022678
# Nodo: 1473 - Centralidad de intermediación: 0.044824348458776204
# Nodo: 3249 - Centralidad de intermediación: 0.04465135249698427
# Nodo: 2938 - Centralidad de intermediación: 0.044651239715533725
# Nodo: 2937 - Centralidad de intermediación: 0.044651126934083164
# Nodo: 3154 - Centralidad de intermediación: 0.0446510141526326
# Nodo: 3122 - Centralidad de intermediación: 0.04459951608137527
# Nodo: 2857 - Centralidad de intermediación: 0.044599403299924706
# Nodo: 2856 - Centralidad de intermediación: 0.044599290518474145
# Nodo: 2490 - Centralidad de intermediación: 0.044599177737023585
# Nodo: 2255 - Centralidad de intermediación: 0.04442715205440471
# Nodo: 2253 - Centralidad de intermediación: 0.04442703927295414
# Nodo: 8367 - Centralidad de intermediación: 0.04428983711645128
# Nodo: 408 - Centralidad de intermediación: 0.04386850472439955
# Nodo: 2738 - Centralidad de intermediación: 0.04372366210064401
# Nodo: 4826 - Centralidad de intermediación: 0.04372354931919346
# Nodo: 12953 - Centralidad de intermediación: 0.04329663466431206
# Nodo: 12954 - Centralidad de intermediación: 0.043296521882861504
# Nodo: 12958 - Centralidad de intermediación: 0.04329640910141094
# Nodo: 12952 - Centralidad de intermediación: 0.043296296319960376
# Nodo: 3251 - Centralidad de intermediación: 0.04303461470230236
# Nodo: 3250 - Centralidad de intermediación: 0.04303450192085181
# Nodo: 10120 - Centralidad de intermediación: 0.04300926916873707
# Nodo: 12955 - Centralidad de intermediación: 0.04280660389047302
# Nodo: 1097 - Centralidad de intermediación: 0.042646117353607446
# Nodo: 3184 - Centralidad de intermediación: 0.04256964559426075
# Nodo: 9110 - Centralidad de intermediación: 0.042565486328000925
# Nodo: 1501 - Centralidad de intermediación: 0.04256254481814824
# Nodo: 3182 - Centralidad de intermediación: 0.04256243203669767
# Nodo: 1474 - Centralidad de intermediación: 0.04254239316171755
# Nodo: 2685 - Centralidad de intermediación: 0.04254228038026701
# Nodo: 6387 - Centralidad de intermediación: 0.0419894496523935
# Nodo: 2826 - Centralidad de intermediación: 0.04166947323567788
# Nodo: 3906 - Centralidad de intermediación: 0.04166936045422732
# Nodo: 3908 - Centralidad de intermediación: 0.04166924767277675
# Nodo: 3907 - Centralidad de intermediación: 0.04166913489132619
# Nodo: 2894 - Centralidad de intermediación: 0.0413566304958418
# Nodo: 3069 - Centralidad de intermediación: 0.041356517714391236
# Nodo: 3256 - Centralidad de intermediación: 0.041248734406543516
# Nodo: 3241 - Centralidad de intermediación: 0.041248621625092956
# Nodo: 11159 - Centralidad de intermediación: 0.04085172304137533
# Nodo: 12965 - Centralidad de intermediación: 0.04069561398677856
# Nodo: 5024 - Centralidad de intermediación: 0.04060488384997531
# Nodo: 5047 - Centralidad de intermediación: 0.04052326596888795
# Nodo: 2905 - Centralidad de intermediación: 0.04041330356441671
# Nodo: 6250 - Centralidad de intermediación: 0.040413190782966145
# Nodo: 5036 - Centralidad de intermediación: 0.040401682005062486
# Nodo: 9122 - Centralidad de intermediación: 0.04035147327213662
# Nodo: 10826 - Centralidad de intermediación: 0.04024003494212996
# Nodo: 8340 - Centralidad de intermediación: 0.03990119920279229
# Nodo: 12364 - Centralidad de intermediación: 0.039622896741527046
# Nodo: 12865 - Centralidad de intermediación: 0.03958881129100112
# Nodo: 3259 - Centralidad de intermediación: 0.03958869850955055
# Nodo: 3068 - Centralidad de intermediación: 0.03955315358103233
# Nodo: 1436 - Centralidad de intermediación: 0.03955304079958175
# Nodo: 11468 - Centralidad de intermediación: 0.03951872494056961
# Nodo: 3361 - Centralidad de intermediación: 0.03903164752120619
# Nodo: 2739 - Centralidad de intermediación: 0.03864276457527382
# Nodo: 9109 - Centralidad de intermediación: 0.038627238950476483
# Nodo: 2362 - Centralidad de intermediación: 0.03827720984738817
# Nodo: 359 - Centralidad de intermediación: 0.03781197018818466
# Nodo: 3242 - Centralidad de intermediación: 0.03688617505260268
# Nodo: 3090 - Centralidad de intermediación: 0.03688606227115211
# Nodo: 12365 - Centralidad de intermediación: 0.036863472169918345
# Nodo: 1371 - Centralidad de intermediación: 0.03673675098426253
# Nodo: 10318 - Centralidad de intermediación: 0.036410231510346655
# Nodo: 69 - Centralidad de intermediación: 0.036379900749729174
# Nodo: 6655 - Centralidad de intermediación: 0.036257960444001244
# Nodo: 2382 - Centralidad de intermediación: 0.036229408879827715
# Nodo: 1333 - Centralidad de intermediación: 0.03605405796624911
# Nodo: 9880 - Centralidad de intermediación: 0.036020003729280985
# Nodo: 3261 - Centralidad de intermediación: 0.03596283867346737
# Nodo: 8341 - Centralidad de intermediación: 0.03573871844392251
# Nodo: 2383 - Centralidad de intermediación: 0.03563786034763621
# Nodo: 11695 - Centralidad de intermediación: 0.03561473831652689
# Nodo: 8352 - Centralidad de intermediación: 0.035193166640437985
# Nodo: 5920 - Centralidad de intermediación: 0.03510527043019439
# Nodo: 398 - Centralidad de intermediación: 0.035069939872382015
# Nodo: 872 - Centralidad de intermediación: 0.03504937819989269
# Nodo: 6011 - Centralidad de intermediación: 0.03504926541844213
# Nodo: 3010 - Centralidad de intermediación: 0.034634664353130735
# Nodo: 5027 - Centralidad de intermediación: 0.03424462627327896
# Nodo: 409 - Centralidad de intermediación: 0.03409933980041179
# Nodo: 2248 - Centralidad de intermediación: 0.03407991161757058
# Nodo: 2823 - Centralidad de intermediación: 0.03407979883612003
# Nodo: 8349 - Centralidad de intermediación: 0.03395367361836845
# Nodo: 1289 - Centralidad de intermediación: 0.03380297344623104
# Nodo: 3011 - Centralidad de intermediación: 0.0337193992501505
# Nodo: 11722 - Centralidad de intermediación: 0.03351354554533196
# Nodo: 7324 - Centralidad de intermediación: 0.03296644650837544
# Nodo: 2520 - Centralidad de intermediación: 0.032858678836650994
# Nodo: 12352 - Centralidad de intermediación: 0.03279332948730254
# Nodo: 4109 - Centralidad de intermediación: 0.03248781529740515
# Nodo: 6246 - Centralidad de intermediación: 0.032463837060329945
# Nodo: 8259 - Centralidad de intermediación: 0.03245181553157873
# Nodo: 2735 - Centralidad de intermediación: 0.03243012095787728
# Nodo: 1663 - Centralidad de intermediación: 0.032339762844485975
# Nodo: 8 - Centralidad de intermediación: 0.032093475199406134
# Nodo: 255 - Centralidad de intermediación: 0.03202777925917893
# Nodo: 9346 - Centralidad de intermediación: 0.03194014308866795
# Nodo: 8346 - Centralidad de intermediación: 0.031542365329628876
# Nodo: 2250 - Centralidad de intermediación: 0.031190031968262935
# Nodo: 2249 - Centralidad de intermediación: 0.031189919186812385
# Nodo: 3035 - Centralidad de intermediación: 0.030965004243994582
# Nodo: 11182 - Centralidad de intermediación: 0.030765740164249423
# Nodo: 11292 - Centralidad de intermediación: 0.030656251759541432
# Nodo: 7169 - Centralidad de intermediación: 0.03055719250313862
# Nodo: 2312 - Centralidad de intermediación: 0.030525353876621582
# Nodo: 7345 - Centralidad de intermediación: 0.02990320743210734
# Nodo: 3227 - Centralidad de intermediación: 0.029844547066508475
# Nodo: 3225 - Centralidad de intermediación: 0.02984443428505787
# Nodo: 3226 - Centralidad de intermediación: 0.02976762418135949
# Nodo: 11000 - Centralidad de intermediación: 0.029733348471530457
# Nodo: 6173 - Centralidad de intermediación: 0.02972235426445221
# Nodo: 12867 - Centralidad de intermediación: 0.029676029514773883
# Nodo: 6277 - Centralidad de intermediación: 0.02962073694789971
# Nodo: 6014 - Centralidad de intermediación: 0.02958487713343425
# Nodo: 4325 - Centralidad de intermediación: 0.029574871217737594
# Nodo: 2907 - Centralidad de intermediación: 0.029570878719589678
# Nodo: 8420 - Centralidad de intermediación: 0.029532593813857734
# Nodo: 873 - Centralidad de intermediación: 0.029339765553765957
# Nodo: 8746 - Centralidad de intermediación: 0.02906256183569625
# Nodo: 1475 - Centralidad de intermediación: 0.029051877443765563
# Nodo: 1502 - Centralidad de intermediación: 0.029051764662315002
# Nodo: 12313 - Centralidad de intermediación: 0.029034316950075693
# Nodo: 7046 - Centralidad de intermediación: 0.028957736690775716
# Nodo: 2432 - Centralidad de intermediación: 0.028918090571564005
# Nodo: 8747 - Centralidad de intermediación: 0.02877755140342584
# Nodo: 3223 - Centralidad de intermediación: 0.028681174978128433
# Nodo: 2627 - Centralidad de intermediación: 0.028681062196677876
# Nodo: 3214 - Centralidad de intermediación: 0.028648817005087698
# Nodo: 3222 - Centralidad de intermediación: 0.02864870422363713
# Nodo: 1123 - Centralidad de intermediación: 0.02847023157431895
# Nodo: 4829 - Centralidad de intermediación: 0.028254794519738332
# Nodo: 4825 - Centralidad de intermediación: 0.028254681738287764
# Nodo: 3086 - Centralidad de intermediación: 0.02824572564416046
# Nodo: 1437 - Centralidad de intermediación: 0.028148240347983477
# Nodo: 3150 - Centralidad de intermediación: 0.028148127566532913
# Nodo: 8390 - Centralidad de intermediación: 0.027999594920678453
# Nodo: 7549 - Centralidad de intermediación: 0.027891411058286054
# Nodo: 3018 - Centralidad de intermediación: 0.02785292943530883
# Nodo: 6009 - Centralidad de intermediación: 0.027815307743608915
# Nodo: 5926 - Centralidad de intermediación: 0.02781519496215836
# Nodo: 11717 - Centralidad de intermediación: 0.02780890603081415
# Nodo: 1665 - Centralidad de intermediación: 0.027785527625642955
# Nodo: 2350 - Centralidad de intermediación: 0.02749476873640047
# Nodo: 2876 - Centralidad de intermediación: 0.0274894825275526
# Nodo: 1525 - Centralidad de intermediación: 0.027489369746102037
# Nodo: 4351 - Centralidad de intermediación: 0.027477941333691722
# Nodo: 4854 - Centralidad de intermediación: 0.027433496439307356
# Nodo: 3117 - Centralidad de intermediación: 0.02739611694012627
# Nodo: 2561 - Centralidad de intermediación: 0.02721228159511307
# Nodo: 9103 - Centralidad de intermediación: 0.02711186213399311
# Nodo: 2563 - Centralidad de intermediación: 0.027108305270784904
# Nodo: 4108 - Centralidad de intermediación: 0.027036089654636643
# Nodo: 3089 - Centralidad de intermediación: 0.02697039384697254
# Nodo: 2485 - Centralidad de intermediación: 0.026970281065521972
# Nodo: 2560 - Centralidad de intermediación: 0.026944057587431545
# Nodo: 2558 - Centralidad de intermediación: 0.026920543071226898
# Nodo: 8428 - Centralidad de intermediación: 0.026916778665481634
# Nodo: 7089 - Centralidad de intermediación: 0.02685856509232685
# Nodo: 5096 - Centralidad de intermediación: 0.02680658898347895
# Nodo: 4057 - Centralidad de intermediación: 0.026654883500077386
# Nodo: 2311 - Centralidad de intermediación: 0.026537836800283265
# Nodo: 3067 - Centralidad de intermediación: 0.026412651676004643
# Nodo: 3179 - Centralidad de intermediación: 0.026412538894554083
# Nodo: 2875 - Centralidad de intermediación: 0.026335728790855693
# Nodo: 2418 - Centralidad de intermediación: 0.02616758168493616
# Nodo: 7525 - Centralidad de intermediación: 0.02608060062995142
# Nodo: 2415 - Centralidad de intermediación: 0.02602430346447494
# Nodo: 6538 - Centralidad de intermediación: 0.0260130686164989
# Nodo: 5919 - Centralidad de intermediación: 0.025987915938461996
# Nodo: 4128 - Centralidad de intermediación: 0.02585294031361341
# Nodo: 71 - Centralidad de intermediación: 0.025846066984286705
# Nodo: 588 - Centralidad de intermediación: 0.025826011499365864
# Nodo: 597 - Centralidad de intermediación: 0.025798650306796206
# Nodo: 7346 - Centralidad de intermediación: 0.025702169041457366
# Nodo: 2389 - Centralidad de intermediación: 0.025578888077518187
# Nodo: 3784 - Centralidad de intermediación: 0.025457677216281522
# Nodo: 958 - Centralidad de intermediación: 0.02538995855421532
# Nodo: 3021 - Centralidad de intermediación: 0.025319184173083188
# Nodo: 2486 - Centralidad de intermediación: 0.025204219691646882
# Nodo: 1747 - Centralidad de intermediación: 0.02519823775079094
# Nodo: 1746 - Centralidad de intermediación: 0.025197899406439253
# Nodo: 2492 - Centralidad de intermediación: 0.02519778662498869
# Nodo: 8439 - Centralidad de intermediación: 0.024911041948988178
# Nodo: 3039 - Centralidad de intermediación: 0.024872031776097907
# Nodo: 3785 - Centralidad de intermediación: 0.024716653751759597
# Nodo: 9971 - Centralidad de intermediación: 0.024605937012459705
# Nodo: 7897 - Centralidad de intermediación: 0.02456730979810981
# Nodo: 9990 - Centralidad de intermediación: 0.024551051375717413
# Nodo: 5381 - Centralidad de intermediación: 0.024549150986043395
# Nodo: 12320 - Centralidad de intermediación: 0.02452687711393518
# Nodo: 12321 - Centralidad de intermediación: 0.02452676433248462
# Nodo: 2736 - Centralidad de intermediación: 0.024415910702752674
# Nodo: 3022 - Centralidad de intermediación: 0.0243540258582639
# Nodo: 4044 - Centralidad de intermediación: 0.02426666080869249
# Nodo: 3120 - Centralidad de intermediación: 0.02420116048582994
# Nodo: 2430 - Centralidad de intermediación: 0.02420104770437938
# Nodo: 12314 - Centralidad de intermediación: 0.023889436517615815
# Nodo: 2374 - Centralidad de intermediación: 0.023881374123267664
# Nodo: 3775 - Centralidad de intermediación: 0.02387514425894088
# Nodo: 695 - Centralidad de intermediación: 0.02373767165572671
# Nodo: 3 - Centralidad de intermediación: 0.023731913362842624
# Nodo: 7349 - Centralidad de intermediación: 0.023620685311747557
# Nodo: 2402 - Centralidad de intermediación: 0.023525756208993717
# Nodo: 12868 - Centralidad de intermediación: 0.023484740689243878
# Nodo: 5086 - Centralidad de intermediación: 0.02346035222535072
# Nodo: 7656 - Centralidad de intermediación: 0.0233222499032606
# Nodo: 5018 - Centralidad de intermediación: 0.02329441036675073
# Nodo: 5371 - Centralidad de intermediación: 0.023294297585300165
# Nodo: 12121 - Centralidad de intermediación: 0.02317088459009559
# Nodo: 8264 - Centralidad de intermediación: 0.02313326685196512
# Nodo: 11065 - Centralidad de intermediación: 0.02312925490510563
# Nodo: 983 - Centralidad de intermediación: 0.02312000522619077
# Nodo: 1339 - Centralidad de intermediación: 0.023119892444740206
# Nodo: 1344 - Centralidad de intermediación: 0.023119779663289645
# Nodo: 1342 - Centralidad de intermediación: 0.02311966688183907
# Nodo: 1343 - Centralidad de intermediación: 0.02311955410038851
# Nodo: 5065 - Centralidad de intermediación: 0.023093904699078936
# Nodo: 2404 - Centralidad de intermediación: 0.02307501213312217
# Nodo: 9317 - Centralidad de intermediación: 0.02305406119630992
# Nodo: 542 - Centralidad de intermediación: 0.023033043882637258
# Nodo: 1742 - Centralidad de intermediación: 0.02299625047762422
# Nodo: 8284 - Centralidad de intermediación: 0.022967787831402013
# Nodo: 4131 - Centralidad de intermediación: 0.02295560650667486
# Nodo: 11006 - Centralidad de intermediación: 0.02295194143049795
# Nodo: 1744 - Centralidad de intermediación: 0.02292166323733842
# Nodo: 1439 - Centralidad de intermediación: 0.02287823706932388
# Nodo: 3066 - Centralidad de intermediación: 0.022878124287873274
# Nodo: 4348 - Centralidad de intermediación: 0.02286014290763128
# Nodo: 80 - Centralidad de intermediación: 0.022852666556921128
# Nodo: 9325 - Centralidad de intermediación: 0.022845916915568937
# Nodo: 7332 - Centralidad de intermediación: 0.022755538779939164
# Nodo: 4354 - Centralidad de intermediación: 0.022748125061265626
# Nodo: 8055 - Centralidad de intermediación: 0.022744056623523363
# Nodo: 3038 - Centralidad de intermediación: 0.02273847307625899
# Nodo: 3236 - Centralidad de intermediación: 0.02273469428460005
# Nodo: 2126 - Centralidad de intermediación: 0.022734581503149488
# Nodo: 6005 - Centralidad de intermediación: 0.022695220896859918
# Nodo: 869 - Centralidad de intermediación: 0.022695108115409365
# Nodo: 665 - Centralidad de intermediación: 0.02269036702619926
# Nodo: 6196 - Centralidad de intermediación: 0.022581833482299193
# Nodo: 10530 - Centralidad de intermediación: 0.022411002145707376
# Nodo: 9209 - Centralidad de intermediación: 0.022317721008299683
# Nodo: 1228 - Centralidad de intermediación: 0.02220778736716661
# Nodo: 11724 - Centralidad de intermediación: 0.02213208930434842
# Nodo: 3172 - Centralidad de intermediación: 0.022105246691836916
# Nodo: 2491 - Centralidad de intermediación: 0.022056597053496357
# Nodo: 2852 - Centralidad de intermediación: 0.022056484272045793
# Nodo: 2853 - Centralidad de intermediación: 0.022056371490595233
# Nodo: 3156 - Centralidad de intermediación: 0.02205625870914467
# Nodo: 5975 - Centralidad de intermediación: 0.022055303932532994
# Nodo: 3155 - Centralidad de intermediación: 0.022030721113802443
# Nodo: 3252 - Centralidad de intermediación: 0.02203060833235189
# Nodo: 617 - Centralidad de intermediación: 0.022009015102240487
# Nodo: 1716 - Centralidad de intermediación: 0.022003567021945773
# Nodo: 7899 - Centralidad de intermediación: 0.021990991453597463
# Nodo: 3167 - Centralidad de intermediación: 0.02191819564968642
# Nodo: 3247 - Centralidad de intermediación: 0.021806750273506398
# Nodo: 3246 - Centralidad de intermediación: 0.021806637492055834
# Nodo: 3248 - Centralidad de intermediación: 0.021753345426024237
# Nodo: 11017 - Centralidad de intermediación: 0.02174152138202869
# Nodo: 3726 - Centralidad de intermediación: 0.021711275177563008
# Nodo: 8765 - Centralidad de intermediación: 0.021706125604900983
# Nodo: 7087 - Centralidad de intermediación: 0.021694607663100895
# Nodo: 3210 - Centralidad de intermediación: 0.02165183573534224
# Nodo: 3112 - Centralidad de intermediación: 0.02165172295389168
# Nodo: 3235 - Centralidad de intermediación: 0.02165093348373774
# Nodo: 3234 - Centralidad de intermediación: 0.021650820702287178
# Nodo: 3194 - Centralidad de intermediación: 0.021587660478383813
# Nodo: 616 - Centralidad de intermediación: 0.021576313729076643
# Nodo: 622 - Centralidad de intermediación: 0.02155418021150109
# Nodo: 420 - Centralidad de intermediación: 0.02154414449740524
# Nodo: 7359 - Centralidad de intermediación: 0.021535601286372934
# Nodo: 1435 - Centralidad de intermediación: 0.02150772075622829
# Nodo: 3944 - Centralidad de intermediación: 0.021221350573810364
# Nodo: 625 - Centralidad de intermediación: 0.02121865371067903
# Nodo: 4666 - Centralidad de intermediación: 0.021214717995189564
# Nodo: 2406 - Centralidad de intermediación: 0.02114913729274022
# Nodo: 11310 - Centralidad de intermediación: 0.02105753433851135
# Nodo: 6015 - Centralidad de intermediación: 0.021052431173412565
# Nodo: 6438 - Centralidad de intermediación: 0.02094962143695139
# Nodo: 5519 - Centralidad de intermediación: 0.020828461199093474
# Nodo: 12848 - Centralidad de intermediación: 0.020786892805273054
# Nodo: 7360 - Centralidad de intermediación: 0.020758301228103182
# Nodo: 10491 - Centralidad de intermediación: 0.020753932914331263
# Nodo: 623 - Centralidad de intermediación: 0.020546616520885536
# Nodo: 1314 - Centralidad de intermediación: 0.020503274904238984
# Nodo: 1760 - Centralidad de intermediación: 0.020491790210279533
# Nodo: 3006 - Centralidad de intermediación: 0.02044877486952462
# Nodo: 1261 - Centralidad de intermediación: 0.02037048734935598
# Nodo: 5593 - Centralidad de intermediación: 0.02021695016664912
# Nodo: 92 - Centralidad de intermediación: 0.020195003008362116
# Nodo: 2890 - Centralidad de intermediación: 0.02014352800735785
# Nodo: 5025 - Centralidad de intermediación: 0.020125896682284962
# Nodo: 9675 - Centralidad de intermediación: 0.02011498915667015
# Nodo: 8363 - Centralidad de intermediación: 0.02005795563736967
# Nodo: 12467 - Centralidad de intermediación: 0.020025548170738046
# Nodo: 1676 - Centralidad de intermediación: 0.019992740644939354
# Nodo: 3007 - Centralidad de intermediación: 0.01996651845081736
# Nodo: 1759 - Centralidad de intermediación: 0.019917726257783538
# Nodo: 2704 - Centralidad de intermediación: 0.019795562133009956
# Nodo: 3217 - Centralidad de intermediación: 0.019795449351559403
# Nodo: 7316 - Centralidad de intermediación: 0.019782939138570772
# Nodo: 1448 - Centralidad de intermediación: 0.019778595258908738
# Nodo: 619 - Centralidad de intermediación: 0.019766598051881048
# Nodo: 6269 - Centralidad de intermediación: 0.01975913389259468
# Nodo: 9540 - Centralidad de intermediación: 0.019723472242763867
# Nodo: 1714 - Centralidad de intermediación: 0.019688198403570608
# Nodo: 3219 - Centralidad de intermediación: 0.019680266701241966
# Nodo: 3218 - Centralidad de intermediación: 0.01968015391979141
# Nodo: 3153 - Centralidad de intermediación: 0.01964711326080318
# Nodo: 1438 - Centralidad de intermediación: 0.019647000479352618
# Nodo: 2483 - Centralidad de intermediación: 0.01962243068722847
# Nodo: 1422 - Centralidad de intermediación: 0.019407567441786525
# Nodo: 7137 - Centralidad de intermediación: 0.01935859300678395
# Nodo: 65 - Centralidad de intermediación: 0.019306075728298535
# Nodo: 8761 - Centralidad de intermediación: 0.0192176235611118
# Nodo: 10827 - Centralidad de intermediación: 0.019126058939770353
# Nodo: 2379 - Centralidad de intermediación: 0.01912395629609194
# Nodo: 2578 - Centralidad de intermediación: 0.019121178900962103
# Nodo: 2351 - Centralidad de intermediación: 0.01911766031542055
# Nodo: 9373 - Centralidad de intermediación: 0.01906540873394964
# Nodo: 6610 - Centralidad de intermediación: 0.019054002187618012
# Nodo: 3662 - Centralidad de intermediación: 0.019053367291656298
# Nodo: 11311 - Centralidad de intermediación: 0.019003194715094637
# Nodo: 3008 - Centralidad de intermediación: 0.01900192952245249
# Nodo: 9876 - Centralidad de intermediación: 0.01900173492622145
# Nodo: 1305 - Centralidad de intermediación: 0.01897175341251185
# Nodo: 5663 - Centralidad de intermediación: 0.018967407998841262
# Nodo: 6913 - Centralidad de intermediación: 0.018881925912207286
# Nodo: 5385 - Centralidad de intermediación: 0.018875622135763315
# Nodo: 2393 - Centralidad de intermediación: 0.018829962552026628
# Nodo: 169 - Centralidad de intermediación: 0.018821780049003478
# Nodo: 5661 - Centralidad de intermediación: 0.018783702914538094
# Nodo: 12249 - Centralidad de intermediación: 0.018741235726236337
# Nodo: 4416 - Centralidad de intermediación: 0.018608143415471685
# Nodo: 8278 - Centralidad de intermediación: 0.018604359346999038
# Nodo: 9139 - Centralidad de intermediación: 0.01859019915502255
# Nodo: 2942 - Centralidad de intermediación: 0.01858543533886978
# Nodo: 1712 - Centralidad de intermediación: 0.018585322557419213
# Nodo: 929 - Centralidad de intermediación: 0.01858520977596866
# Nodo: 3204 - Centralidad de intermediación: 0.01858476240130041
# Nodo: 3240 - Centralidad de intermediación: 0.01858464961984986
# Nodo: 12363 - Centralidad de intermediación: 0.018565496224360472
# Nodo: 7305 - Centralidad de intermediación: 0.01853939986367392
# Nodo: 1420 - Centralidad de intermediación: 0.0185325028105349
# Nodo: 11589 - Centralidad de intermediación: 0.0185071054938202
# Nodo: 9289 - Centralidad de intermediación: 0.01848925494748004
# Nodo: 2825 - Centralidad de intermediación: 0.018449819005448908
# Nodo: 2215 - Centralidad de intermediación: 0.018442500261467803
# Nodo: 7173 - Centralidad de intermediación: 0.0184369942997697
# Nodo: 2360 - Centralidad de intermediación: 0.0184266403810605
# Nodo: 7622 - Centralidad de intermediación: 0.0183480777415332
# Nodo: 7135 - Centralidad de intermediación: 0.018322137682403615
# Nodo: 539 - Centralidad de intermediación: 0.018283542881219014
# Nodo: 1337 - Centralidad de intermediación: 0.01824100617730901
# Nodo: 5923 - Centralidad de intermediación: 0.01820453026589777
# Nodo: 5939 - Centralidad de intermediación: 0.018204417484447205
# Nodo: 6012 - Centralidad de intermediación: 0.018204304702996645
# Nodo: 6651 - Centralidad de intermediación: 0.01816119408803307
# Nodo: 6776 - Centralidad de intermediación: 0.018027236626792835
# Nodo: 3947 - Centralidad de intermediación: 0.01801229989966313
# Nodo: 1121 - Centralidad de intermediación: 0.017960130225111788
# Nodo: 6773 - Centralidad de intermediación: 0.017955628534282644
# Nodo: 12394 - Centralidad de intermediación: 0.017936979997100293
# Nodo: 7177 - Centralidad de intermediación: 0.017934787115475102
# Nodo: 11304 - Centralidad de intermediación: 0.0178938105503583
# Nodo: 5928 - Centralidad de intermediación: 0.017841218415353122
# Nodo: 2261 - Centralidad de intermediación: 0.01781067019535795
# Nodo: 68 - Centralidad de intermediación: 0.017803817402165304
# Nodo: 3151 - Centralidad de intermediación: 0.01778645511342458
# Nodo: 1271 - Centralidad de intermediación: 0.017786342331974018
# Nodo: 12973 - Centralidad de intermediación: 0.017780337120760582
# Nodo: 519 - Centralidad de intermediación: 0.017773786428677787
# Nodo: 10493 - Centralidad de intermediación: 0.01769265931523834
# Nodo: 1713 - Centralidad de intermediación: 0.017660309418784468
# Nodo: 10419 - Centralidad de intermediación: 0.017614612477659705
# Nodo: 1270 - Centralidad de intermediación: 0.017599403836188986
# Nodo: 1780 - Centralidad de intermediación: 0.017599291054738418
# Nodo: 11299 - Centralidad de intermediación: 0.017572971869385053
# Nodo: 412 - Centralidad de intermediación: 0.017571686545655968
# Nodo: 10894 - Centralidad de intermediación: 0.017569291921609297
# Nodo: 1787 - Centralidad de intermediación: 0.017522480951040028
# Nodo: 5083 - Centralidad de intermediación: 0.017501417878430858
# Nodo: 1120 - Centralidad de intermediación: 0.017491881764115216
# Nodo: 7553 - Centralidad de intermediación: 0.017491631799748778
# Nodo: 2216 - Centralidad de intermediación: 0.017472188062277537
# Nodo: 2264 - Centralidad de intermediación: 0.017461728405597236
# Nodo: 2924 - Centralidad de intermediación: 0.017457187339429463
# Nodo: 609 - Centralidad de intermediación: 0.01741312544652639
# Nodo: 5970 - Centralidad de intermediación: 0.017380576226186335
# Nodo: 5922 - Centralidad de intermediación: 0.017380404364452547
# Nodo: 5921 - Centralidad de intermediación: 0.017380291583001986
# Nodo: 6161 - Centralidad de intermediación: 0.017362472085430625
# Nodo: 2356 - Centralidad de intermediación: 0.017312042386457976
# Nodo: 4470 - Centralidad de intermediación: 0.017259998979244993
# Nodo: 591 - Centralidad de intermediación: 0.017248290932041492
# Nodo: 7457 - Centralidad de intermediación: 0.017220148922876495
# Nodo: 2650 - Centralidad de intermediación: 0.01721761497021225
# Nodo: 9486 - Centralidad de intermediación: 0.017199381740455297
# Nodo: 5969 - Centralidad de intermediación: 0.01717576827140975
# Nodo: 1122 - Centralidad de intermediación: 0.017174559227224703
# Nodo: 384 - Centralidad de intermediación: 0.01716636675382705
# Nodo: 5678 - Centralidad de intermediación: 0.01714982782054311
# Nodo: 2742 - Centralidad de intermediación: 0.017146808055485963
# Nodo: 2743 - Centralidad de intermediación: 0.017146695274035402
# Nodo: 2944 - Centralidad de intermediación: 0.01714658249258484
# Nodo: 11293 - Centralidad de intermediación: 0.017128431176215608
# Nodo: 34 - Centralidad de intermediación: 0.017101974023857398
# Nodo: 2866 - Centralidad de intermediación: 0.01708002646759864
# Nodo: 1224 - Centralidad de intermediación: 0.017071075027878142
# Nodo: 11298 - Centralidad de intermediación: 0.01704539315143459
# Nodo: 1366 - Centralidad de intermediación: 0.017031364771198865
# Nodo: 5522 - Centralidad de intermediación: 0.016972050955650946
# Nodo: 7528 - Centralidad de intermediación: 0.016964472054726867
# Nodo: 611 - Centralidad de intermediación: 0.01691505938444715
# Nodo: 2498 - Centralidad de intermediación: 0.016908070253764267
# Nodo: 32 - Centralidad de intermediación: 0.016903808819689968
# Nodo: 1230 - Centralidad de intermediación: 0.016828065189229188
# Nodo: 9101 - Centralidad de intermediación: 0.01682494778265331
# Nodo: 5971 - Centralidad de intermediación: 0.016792502070459986
# Nodo: 8343 - Centralidad de intermediación: 0.016756649507858885
# Nodo: 7080 - Centralidad de intermediación: 0.01669179943020976
# Nodo: 6657 - Centralidad de intermediación: 0.016599690308443816
# Nodo: 5974 - Centralidad de intermediación: 0.016588563662247726
# Nodo: 5276 - Centralidad de intermediación: 0.016580135327422828
# Nodo: 1670 - Centralidad de intermediación: 0.016572465811351224
# Nodo: 3482 - Centralidad de intermediación: 0.016561391621244093
# Nodo: 8361 - Centralidad de intermediación: 0.016551511267267068
# Nodo: 6653 - Centralidad de intermediación: 0.016548217550328984
# Nodo: 5557 - Centralidad de intermediación: 0.01654810476887843
# Nodo: 5525 - Centralidad de intermediación: 0.01654799198742789
# Nodo: 5062 - Centralidad de intermediación: 0.01650769381421368
# Nodo: 4365 - Centralidad de intermediación: 0.016502576247009227
# Nodo: 166 - Centralidad de intermediación: 0.016500612149386314
# Nodo: 6660 - Centralidad de intermediación: 0.01649113001761366
# Nodo: 12386 - Centralidad de intermediación: 0.016485676025529156
# Nodo: 12381 - Centralidad de intermediación: 0.016485563244078596
# Nodo: 7449 - Centralidad de intermediación: 0.016443796723113725
# Nodo: 4091 - Centralidad de intermediación: 0.016410885959529827
# Nodo: 6174 - Centralidad de intermediación: 0.016398679673064784
# Nodo: 9814 - Centralidad de intermediación: 0.01639617320846341
# Nodo: 7136 - Centralidad de intermediación: 0.01639380893691531
# Nodo: 637 - Centralidad de intermediación: 0.016392766946770377
# Nodo: 1222 - Centralidad de intermediación: 0.0163635346074213
# Nodo: 886 - Centralidad de intermediación: 0.01636342182597075
# Nodo: 3781 - Centralidad de intermediación: 0.01632919809578836
# Nodo: 7085 - Centralidad de intermediación: 0.01632322697987342
# Nodo: 4366 - Centralidad de intermediación: 0.01632122673027959
# Nodo: 58 - Centralidad de intermediación: 0.016320913999198404
# Nodo: 8049 - Centralidad de intermediación: 0.016309513635332767
# Nodo: 599 - Centralidad de intermediación: 0.016278721666712657
# Nodo: 6797 - Centralidad de intermediación: 0.016273619600237547
# Nodo: 432 - Centralidad de intermediación: 0.016268129807503532
# Nodo: 12387 - Centralidad de intermediación: 0.01623654686288821
# Nodo: 6442 - Centralidad de intermediación: 0.016159754300128535
# Nodo: 4387 - Centralidad de intermediación: 0.016003892151302518
# Nodo: 6800 - Centralidad de intermediación: 0.01599489832476034
# Nodo: 2878 - Centralidad de intermediación: 0.015953934843953493
# Nodo: 3158 - Centralidad de intermediación: 0.01595382206250293
# Nodo: 3095 - Centralidad de intermediación: 0.01595370928105237
# Nodo: 7088 - Centralidad de intermediación: 0.01594739265467578
# Nodo: 6547 - Centralidad de intermediación: 0.01593716267466256
# Nodo: 1786 - Centralidad de intermediación: 0.01589588327725857
# Nodo: 1386 - Centralidad de intermediación: 0.015895770495808016
# Nodo: 3238 - Centralidad de intermediación: 0.01583366335653265
# Nodo: 3237 - Centralidad de intermediación: 0.015833550575082112
# Nodo: 3239 - Centralidad de intermediación: 0.015832986667829323
# Nodo: 3208 - Centralidad de intermediación: 0.015832873886378773
# Nodo: 2262 - Centralidad de intermediación: 0.0157658430559482
# Nodo: 4120 - Centralidad de intermediación: 0.01575505590405972
# Nodo: 12155 - Centralidad de intermediación: 0.01574612687656269
# Nodo: 11295 - Centralidad de intermediación: 0.015720706418839017
# Nodo: 4111 - Centralidad de intermediación: 0.01571013820431699
# Nodo: 12110 - Centralidad de intermediación: 0.015700632661555233
# Nodo: 9658 - Centralidad de intermediación: 0.015684223647623122
# Nodo: 6 - Centralidad de intermediación: 0.015681430553151958
# Nodo: 1743 - Centralidad de intermediación: 0.015663912624509835
# Nodo: 5517 - Centralidad de intermediación: 0.015661804333951965
# Nodo: 541 - Centralidad de intermediación: 0.01565985227700029
# Nodo: 992 - Centralidad de intermediación: 0.015642649591701592
# Nodo: 9135 - Centralidad de intermediación: 0.01563426756642544
# Nodo: 6838 - Centralidad de intermediación: 0.01555714314703421
# Nodo: 3942 - Centralidad de intermediación: 0.015547465077081915
# Nodo: 520 - Centralidad de intermediación: 0.015536958502618062
# Nodo: 5664 - Centralidad de intermediación: 0.015445976647565859
# Nodo: 11707 - Centralidad de intermediación: 0.0154383362061333
# Nodo: 2368 - Centralidad de intermediación: 0.015389146787188267
# Nodo: 8934 - Centralidad de intermediación: 0.015330295444537444
# Nodo: 3199 - Centralidad de intermediación: 0.01531515199426114
# Nodo: 3211 - Centralidad de intermediación: 0.015315039212810572
# Nodo: 3099 - Centralidad de intermediación: 0.015300373278901758
# Nodo: 3097 - Centralidad de intermediación: 0.015300260497451193
# Nodo: 7509 - Centralidad de intermediación: 0.01526599763130705
# Nodo: 3666 - Centralidad de intermediación: 0.015260135621722208
# Nodo: 6385 - Centralidad de intermediación: 0.015251202125641338
# Nodo: 4757 - Centralidad de intermediación: 0.015235841413380299
# Nodo: 7306 - Centralidad de intermediación: 0.015193201080019125
# Nodo: 7527 - Centralidad de intermediación: 0.015190299536251239
# Nodo: 10489 - Centralidad de intermediación: 0.01511810377677853
# Nodo: 12319 - Centralidad de intermediación: 0.015117990995328016
# Nodo: 7448 - Centralidad de intermediación: 0.015113058410855642
# Nodo: 809 - Centralidad de intermediación: 0.01509880875581841
# Nodo: 10590 - Centralidad de intermediación: 0.015074045307973554
# Nodo: 426 - Centralidad de intermediación: 0.015050613869869688
# Nodo: 10880 - Centralidad de intermediación: 0.015024094919149186
# Nodo: 12357 - Centralidad de intermediación: 0.014965767114725737
# Nodo: 5049 - Centralidad de intermediación: 0.014935531582401915
# Nodo: 4265 - Centralidad de intermediación: 0.014898000512410704
# Nodo: 8423 - Centralidad de intermediación: 0.014865052467755543
# Nodo: 8418 - Centralidad de intermediación: 0.01486151698362253
# Nodo: 8425 - Centralidad de intermediación: 0.014859933949280193
# Nodo: 7323 - Centralidad de intermediación: 0.014813771345990713
# Nodo: 6386 - Centralidad de intermediación: 0.014800868435138958
# Nodo: 6483 - Centralidad de intermediación: 0.014771964496778808
# Nodo: 3778 - Centralidad de intermediación: 0.014695907015814802
# Nodo: 1405 - Centralidad de intermediación: 0.014679834435767631
# Nodo: 5081 - Centralidad de intermediación: 0.014655628975418764
# Nodo: 11985 - Centralidad de intermediación: 0.014632705204567725
# Nodo: 6485 - Centralidad de intermediación: 0.014569944458856732
# Nodo: 4063 - Centralidad de intermediación: 0.014563923859263547
# Nodo: 11716 - Centralidad de intermediación: 0.01455636661342661
# Nodo: 4658 - Centralidad de intermediación: 0.014539301253350722
# Nodo: 7303 - Centralidad de intermediación: 0.014511112259412146
# Nodo: 6990 - Centralidad de intermediación: 0.014503167802035156
# Nodo: 9086 - Centralidad de intermediación: 0.014451194224277148
# Nodo: 1416 - Centralidad de intermediación: 0.014434090686786189
# Nodo: 3149 - Centralidad de intermediación: 0.014433977905335616
# Nodo: 3363 - Centralidad de intermediación: 0.014432551796452767
# Nodo: 11179 - Centralidad de intermediación: 0.014432439015002203
# Nodo: 789 - Centralidad de intermediación: 0.01439931252642176
# Nodo: 4340 - Centralidad de intermediación: 0.0143902793826517
# Nodo: 9093 - Centralidad de intermediación: 0.014347866770697932
# Nodo: 10755 - Centralidad de intermediación: 0.01429298934528912
# Nodo: 1447 - Centralidad de intermediación: 0.014232907393522478
# Nodo: 11040 - Centralidad de intermediación: 0.014212893734767026
# Nodo: 6861 - Centralidad de intermediación: 0.014208561059786465
# Nodo: 12161 - Centralidad de intermediación: 0.014187109204274835
# Nodo: 6794 - Centralidad de intermediación: 0.014183368053927453
# Nodo: 12851 - Centralidad de intermediación: 0.01417943335528487
# Nodo: 7091 - Centralidad de intermediación: 0.014178703010492302
# Nodo: 10756 - Centralidad de intermediación: 0.014172108099330404
# Nodo: 5077 - Centralidad de intermediación: 0.014166094522057525
# Nodo: 1286 - Centralidad de intermediación: 0.014128724099485339
# Nodo: 12397 - Centralidad de intermediación: 0.014121288349904141
# Nodo: 11016 - Centralidad de intermediación: 0.014119455788178742
# Nodo: 1039 - Centralidad de intermediación: 0.014109155805743073
# Nodo: 2830 - Centralidad de intermediación: 0.014094415393300452
# Nodo: 11045 - Centralidad de intermediación: 0.014086317454594367
# Nodo: 12271 - Centralidad de intermediación: 0.0140648382849389
# Nodo: 1313 - Centralidad de intermediación: 0.014041439248838125
# Nodo: 11725 - Centralidad de intermediación: 0.01397995178132213
# Nodo: 3550 - Centralidad de intermediación: 0.013968127669277885
# Nodo: 12226 - Centralidad de intermediación: 0.013964096717368132
# Nodo: 10076 - Centralidad de intermediación: 0.013934523761698665
# Nodo: 7343 - Centralidad de intermediación: 0.013929020288568012
# Nodo: 88 - Centralidad de intermediación: 0.013922059242868347
# Nodo: 10610 - Centralidad de intermediación: 0.013894368876184634
# Nodo: 238 - Centralidad de intermediación: 0.013858741978761387
# Nodo: 8248 - Centralidad de intermediación: 0.01385005185934733
# Nodo: 3904 - Centralidad de intermediación: 0.013849242468230428
# Nodo: 1396 - Centralidad de intermediación: 0.013831012295715059
# Nodo: 9312 - Centralidad de intermediación: 0.013817627471782057
# Nodo: 8675 - Centralidad de intermediación: 0.013799771066913357
# Nodo: 1664 - Centralidad de intermediación: 0.013783686842293369
# Nodo: 6995 - Centralidad de intermediación: 0.01376876855609187
# Nodo: 7036 - Centralidad de intermediación: 0.01369167499581845
# Nodo: 1392 - Centralidad de intermediación: 0.01368530275924047
# Nodo: 7094 - Centralidad de intermediación: 0.013678487411452453
# Nodo: 1588 - Centralidad de intermediación: 0.013615949146855731
# Nodo: 2386 - Centralidad de intermediación: 0.01354476392397779
# Nodo: 7662 - Centralidad de intermediación: 0.013538941178699018
# Nodo: 5029 - Centralidad de intermediación: 0.013483754087997107
# Nodo: 1647 - Centralidad de intermediación: 0.013446997025754004
# Nodo: 12398 - Centralidad de intermediación: 0.013433288566305967
# Nodo: 6843 - Centralidad de intermediación: 0.0134327239376384
# Nodo: 4860 - Centralidad de intermediación: 0.013427885696847846
# Nodo: 11720 - Centralidad de intermediación: 0.013386877104347274
# Nodo: 406 - Centralidad de intermediación: 0.013368309817517294
# ...
# Nodo: 5336 - Centralidad de intermediación: 0.013209683600833627
# Nodo: 1998 - Centralidad de intermediación: 0.013201154201188593
# Nodo: 5382 - Centralidad de intermediación: 0.013193565324359403
# Nodo: 7358 - Centralidad de intermediación: 0.013177113702220473
# Nodo: 4081 - Centralidad de intermediación: 0.013160299998754092
# Nodo: 2259 - Centralidad de intermediación: 0.013159893692489363
# Nodo: 8672 - Centralidad de intermediación: 0.013153792706983209
# Nodo: 5429 - Centralidad de intermediación: 0.013119371641135602
# Nodo: 5434 - Centralidad de intermediación: 0.013119258859685044
# Nodo: 5475 - Centralidad de intermediación: 0.013119146078234478
# Nodo: 10589 - Centralidad de intermediación: 0.013115232099846733
# Nodo: 8102 - Centralidad de intermediación: 0.013044503347942039
# Nodo: 10835 - Centralidad de intermediación: 0.013037852934520708
# Nodo: 8103 - Centralidad de intermediación: 0.013021800795689034
# Nodo: 1241 - Centralidad de intermediación: 0.013017249644274203
# Nodo: 10316 - Centralidad de intermediación: 0.013010075314689696
# Nodo: 410 - Centralidad de intermediación: 0.013007329178290526
# Nodo: 7446 - Centralidad de intermediación: 0.01300634813500366
# Nodo: 7092 - Centralidad de intermediación: 0.01299336657687211
# Nodo: 12250 - Centralidad de intermediación: 0.012988688572495995
# Nodo: 12227 - Centralidad de intermediación: 0.012988575791045433
# Nodo: 11469 - Centralidad de intermediación: 0.012982036568230389
# Nodo: 5640 - Centralidad de intermediación: 0.012970722026076163
# Nodo: 4385 - Centralidad de intermediación: 0.012913841779380819
# Nodo: 7314 - Centralidad de intermediación: 0.01287788372723608
# Nodo: 8773 - Centralidad de intermediación: 0.01286722164816902
# Nodo: 6224 - Centralidad de intermediación: 0.012846035433745066
# Nodo: 9555 - Centralidad de intermediación: 0.012844927903777363
# Nodo: 7450 - Centralidad de intermediación: 0.012825813522154696
# Nodo: 217 - Centralidad de intermediación: 0.012794745161483864
# Nodo: 2572 - Centralidad de intermediación: 0.012793936725550034
# Nodo: 5341 - Centralidad de intermediación: 0.012772720389604739
# Nodo: 6591 - Centralidad de intermediación: 0.012748783710108288
# Nodo: 4064 - Centralidad de intermediación: 0.012746867922556495
# Nodo: 8416 - Centralidad de intermediación: 0.01274153922370934
# Nodo: 3041 - Centralidad de intermediación: 0.012715393392307404
# Nodo: 3310 - Centralidad de intermediación: 0.01270719300279055
# Nodo: 7789 - Centralidad de intermediación: 0.012694848506650352
# Nodo: 8394 - Centralidad de intermediación: 0.012675224134157177
# Nodo: 6880 - Centralidad de intermediación: 0.012668737542042431
# Nodo: 8053 - Centralidad de intermediación: 0.012648660183140769
# Nodo: 5394 - Centralidad de intermediación: 0.012638775913517197
# Nodo: 4184 - Centralidad de intermediación: 0.012609678070438422
# Nodo: 4112 - Centralidad de intermediación: 0.012606036117056183
# Nodo: 12499 - Centralidad de intermediación: 0.012602410119015422
# Nodo: 7649 - Centralidad de intermediación: 0.01259385729525682
# Nodo: 807 - Centralidad de intermediación: 0.01257604557137717
# Nodo: 364 - Centralidad de intermediación: 0.012575109647425798
# Nodo: 9834 - Centralidad de intermediación: 0.012571952932179583
# Nodo: 7297 - Centralidad de intermediación: 0.012571051731160802
# Nodo: 1147 - Centralidad de intermediación: 0.012565685611122455
# Nodo: 5516 - Centralidad de intermediación: 0.012564220743965704
# Nodo: 6197 - Centralidad de intermediación: 0.012563705909108427
# Nodo: 4313 - Centralidad de intermediación: 0.012543816405758159
# Nodo: 5127 - Centralidad de intermediación: 0.01254058740929963
# Nodo: 7451 - Centralidad de intermediación: 0.012526897348557975
# Nodo: 52 - Centralidad de intermediación: 0.012512010821919162
# Nodo: 196 - Centralidad de intermediación: 0.012480704039600362
# Nodo: 11066 - Centralidad de intermediación: 0.012473371157731497
# Nodo: 9488 - Centralidad de intermediación: 0.012456292407706761
# Nodo: 12792 - Centralidad de intermediación: 0.01243937594790283
# Nodo: 5511 - Centralidad de intermediación: 0.012434909283681753
# Nodo: 5521 - Centralidad de intermediación: 0.012432751164751248
# Nodo: 2675 - Centralidad de intermediación: 0.012432405957477787
# Nodo: 3209 - Centralidad de intermediación: 0.012428778757320602
# Nodo: 3202 - Centralidad de intermediación: 0.012428665975870045
# Nodo: 5334 - Centralidad de intermediación: 0.012413417125965175
# Nodo: 5477 - Centralidad de intermediación: 0.012411993669189898
# Nodo: 3757 - Centralidad de intermediación: 0.012406543584151952
# Nodo: 9569 - Centralidad de intermediación: 0.01236350842466298
# Nodo: 12751 - Centralidad de intermediación: 0.01235966198686994
# Nodo: 7293 - Centralidad de intermediación: 0.012351089281365683
# Nodo: 7047 - Centralidad de intermediación: 0.012349495081583393
# Nodo: 2799 - Centralidad de intermediación: 0.012341541059338452
# Nodo: 6466 - Centralidad de intermediación: 0.012335036688781467
# Nodo: 5528 - Centralidad de intermediación: 0.01231714048135727
# Nodo: 4047 - Centralidad de intermediación: 0.012304872494054339
# Nodo: 7096 - Centralidad de intermediación: 0.012288395560935007
# Nodo: 1315 - Centralidad de intermediación: 0.012267426195066631
# Nodo: 1563 - Centralidad de intermediación: 0.012267313413616072
# Nodo: 367 - Centralidad de intermediación: 0.012264548242435842
# Nodo: 1562 - Centralidad de intermediación: 0.012263253808396
# Nodo: 10745 - Centralidad de intermediación: 0.012229373738162075
# Nodo: 12752 - Centralidad de intermediación: 0.012226730731332191
# Nodo: 10013 - Centralidad de intermediación: 0.012206934437335306
# Nodo: 4863 - Centralidad de intermediación: 0.012204394307559461
# Nodo: 12375 - Centralidad de intermediación: 0.012201383954559176
# Nodo: 9852 - Centralidad de intermediación: 0.012184186427365266
# Nodo: 6543 - Centralidad de intermediación: 0.01217747241526147
# Nodo: 6652 - Centralidad de intermediación: 0.01217668868249753
# Nodo: 4121 - Centralidad de intermediación: 0.012171979072418076
# Nodo: 1246 - Centralidad de intermediación: 0.012169837862532765
# Nodo: 5013 - Centralidad de intermediación: 0.012147667969097093
# Nodo: 715 - Centralidad de intermediación: 0.012143571110275383
# Nodo: 3493 - Centralidad de intermediación: 0.012139702644291657
# Nodo: 10615 - Centralidad de intermediación: 0.012131101823086899
# Nodo: 10948 - Centralidad de intermediación: 0.012124861637769106
# Nodo: 12757 - Centralidad de intermediación: 0.01212047231938742
# Nodo: 3494 - Centralidad de intermediación: 0.012120420396260169
# Nodo: 5668 - Centralidad de intermediación: 0.012118771972107568
# Nodo: 3096 - Centralidad de intermediación: 0.012105857375563132
# Nodo: 3098 - Centralidad de intermediación: 0.01210574459411257
# Nodo: 4866 - Centralidad de intermediación: 0.012105380930510343
# Nodo: 3205 - Centralidad de intermediación: 0.012098499276312886
# Nodo: 12374 - Centralidad de intermediación: 0.012093482471887906
# Nodo: 5051 - Centralidad de intermediación: 0.012077649019069032
# Nodo: 12231 - Centralidad de intermediación: 0.012069459169713064
# Nodo: 1244 - Centralidad de intermediación: 0.012061144073955646
# Nodo: 9966 - Centralidad de intermediación: 0.01205704958337064
# Nodo: 9832 - Centralidad de intermediación: 0.012053459450677888
# Nodo: 2384 - Centralidad de intermediación: 0.012046088591887978
# Nodo: 4268 - Centralidad de intermediación: 0.01204605772380257
# Nodo: 2378 - Centralidad de intermediación: 0.01204597581043741
# Nodo: 6704 - Centralidad de intermediación: 0.012039817648566799
# Nodo: 7791 - Centralidad de intermediación: 0.012036131243100255
# Nodo: 5397 - Centralidad de intermediación: 0.012009307329584778
# Nodo: 4093 - Centralidad de intermediación: 0.012006938953230751
# Nodo: 583 - Centralidad de intermediación: 0.012006556951127675
# Nodo: 5331 - Centralidad de intermediación: 0.01199402344386499
# Nodo: 9208 - Centralidad de intermediación: 0.011993724932631762
# Nodo: 6428 - Centralidad de intermediación: 0.01198457477233966
# Nodo: 8727 - Centralidad de intermediación: 0.011979167407932282
# Nodo: 381 - Centralidad de intermediación: 0.011978877456134157
# Nodo: 699 - Centralidad de intermediación: 0.011975042596049923
# Nodo: 8725 - Centralidad de intermediación: 0.011937783036704919
# Nodo: 2488 - Centralidad de intermediación: 0.011925115559889763
# Nodo: 5399 - Centralidad de intermediación: 0.011924390051230594
# Nodo: 5398 - Centralidad de intermediación: 0.011924277269780029
# Nodo: 12366 - Centralidad de intermediación: 0.011920712287143129
# Nodo: 10997 - Centralidad de intermediación: 0.011920599505692568
# Nodo: 9867 - Centralidad de intermediación: 0.011895968753297438
# Nodo: 2479 - Centralidad de intermediación: 0.011885387643567513
# Nodo: 3854 - Centralidad de intermediación: 0.011875184892872679
# Nodo: 1365 - Centralidad de intermediación: 0.011865388904935468
# Nodo: 2083 - Centralidad de intermediación: 0.011863123590946625
# Nodo: 2480 - Centralidad de intermediación: 0.01185734494491697
# Nodo: 10847 - Centralidad de intermediación: 0.011855446944561915
# Nodo: 1763 - Centralidad de intermediación: 0.011843116395289397
# Nodo: 10958 - Centralidad de intermediación: 0.011842970315890147
# Nodo: 38 - Centralidad de intermediación: 0.011832480336228116
# Nodo: 2496 - Centralidad de intermediación: 0.011821387062625494
# Nodo: 1764 - Centralidad de intermediación: 0.011806715241093514
# Nodo: 5979 - Centralidad de intermediación: 0.011805432573161726
# Nodo: 9844 - Centralidad de intermediación: 0.011801823577935083
# Nodo: 6908 - Centralidad de intermediación: 0.011797342260629767
# Nodo: 12816 - Centralidad de intermediación: 0.011793828172689412
# Nodo: 7628 - Centralidad de intermediación: 0.01177236175960696
# Nodo: 12627 - Centralidad de intermediación: 0.01175218055108709
# Nodo: 2229 - Centralidad de intermediación: 0.011751817983930032
# Nodo: 2787 - Centralidad de intermediación: 0.01175170520247947
# Nodo: 2816 - Centralidad de intermediación: 0.01175159242102891
# Nodo: 9493 - Centralidad de intermediación: 0.011749981100023621
# Nodo: 9495 - Centralidad de intermediación: 0.011739468201799162
# Nodo: 7184 - Centralidad de intermediación: 0.011723694823379621
# Nodo: 12758 - Centralidad de intermediación: 0.011719251717770445
# Nodo: 12801 - Centralidad de intermediación: 0.011714453863488686
# Nodo: 7176 - Centralidad de intermediación: 0.011694937340311134
# Nodo: 11323 - Centralidad de intermediación: 0.011694824558860572
# Nodo: 7650 - Centralidad de intermediación: 0.011691693743739504
# Nodo: 6081 - Centralidad de intermediación: 0.011680834382146137
# Nodo: 51 - Centralidad de intermediación: 0.011666437544889247
# Nodo: 7186 - Centralidad de intermediación: 0.011650551429795984
# Nodo: 5037 - Centralidad de intermediación: 0.011645546341549285
# Nodo: 12908 - Centralidad de intermediación: 0.011631612469761134
# Nodo: 7556 - Centralidad de intermediación: 0.011618904225679473
# Nodo: 4115 - Centralidad de intermediación: 0.01161238980818817
# Nodo: 736 - Centralidad de intermediación: 0.011594532111862713
# Nodo: 10951 - Centralidad de intermediación: 0.011567166522023465
# Nodo: 7223 - Centralidad de intermediación: 0.011558430516048998
# Nodo: 1334 - Centralidad de intermediación: 0.011537723165310354
# Nodo: 4926 - Centralidad de intermediación: 0.011526430725696259
# Nodo: 6222 - Centralidad de intermediación: 0.011514018225168683
# Nodo: 1444 - Centralidad de intermediación: 0.011504775890562986
# Nodo: 11156 - Centralidad de intermediación: 0.011503432203966596
# Nodo: 5349 - Centralidad de intermediación: 0.011491163278734754
# Nodo: 5347 - Centralidad de intermediación: 0.011491050497284194
# Nodo: 2923 - Centralidad de intermediación: 0.011488783557699443
# Nodo: 3551 - Centralidad de intermediación: 0.011487940626539834
# Nodo: 1669 - Centralidad de intermediación: 0.011476533526657161
# Nodo: 10424 - Centralidad de intermediación: 0.011443560431466875
# Nodo: 9374 - Centralidad de intermediación: 0.011436775602646327
# Nodo: 8496 - Centralidad de intermediación: 0.011427353449718507
# Nodo: 4367 - Centralidad de intermediación: 0.011413155648674818
# Nodo: 7158 - Centralidad de intermediación: 0.011406465546118936
# Nodo: 5556 - Centralidad de intermediación: 0.011369200627933816
# Nodo: 6425 - Centralidad de intermediación: 0.011351019424725836
# Nodo: 2832 - Centralidad de intermediación: 0.011341097680675455
# Nodo: 5998 - Centralidad de intermediación: 0.011322006066047196
# Nodo: 7215 - Centralidad de intermediación: 0.011320915631487008
# Nodo: 12628 - Centralidad de intermediación: 0.011305481539323882
# Nodo: 5607 - Centralidad de intermediación: 0.011298984790331099
# Nodo: 12396 - Centralidad de intermediación: 0.011295808237434304
# Nodo: 12390 - Centralidad de intermediación: 0.011295695455983744
# Nodo: 12240 - Centralidad de intermediación: 0.011294377272472506
# Nodo: 6649 - Centralidad de intermediación: 0.011293954019108144
# Nodo: 5553 - Centralidad de intermediación: 0.011290822123369225
# Nodo: 12767 - Centralidad de intermediación: 0.011277193068898001
# Nodo: 658 - Centralidad de intermediación: 0.011265869726211512
# Nodo: 3152 - Centralidad de intermediación: 0.011263169654697902
# Nodo: 6431 - Centralidad de intermediación: 0.011250614071208772
# Nodo: 11713 - Centralidad de intermediación: 0.011247422186585103
# Nodo: 5554 - Centralidad de intermediación: 0.011245613815587554
# Nodo: 717 - Centralidad de intermediación: 0.011244612748026267
# Nodo: 5518 - Centralidad de intermediación: 0.011232021583076669
# Nodo: 6928 - Centralidad de intermediación: 0.011220884357936004
# Nodo: 533 - Centralidad de intermediación: 0.011218472096297075
# Nodo: 11715 - Centralidad de intermediación: 0.011216066336034182
# Nodo: 9967 - Centralidad de intermediación: 0.011215604207292278
# Nodo: 10074 - Centralidad de intermediación: 0.011200960216566637
# Nodo: 3752 - Centralidad de intermediación: 0.011195991945065924
# Nodo: 9842 - Centralidad de intermediación: 0.0111948155179505
# Nodo: 5346 - Centralidad de intermediación: 0.011194422925216415
# Nodo: 5431 - Centralidad de intermediación: 0.011194310143765856
# Nodo: 4010 - Centralidad de intermediación: 0.011194197362315297
# Nodo: 6909 - Centralidad de intermediación: 0.011191673622284083
# Nodo: 12815 - Centralidad de intermediación: 0.011178879998623499
# Nodo: 9323 - Centralidad de intermediación: 0.011178281597280489
# Nodo: 383 - Centralidad de intermediación: 0.011174100840755817
# Nodo: 9085 - Centralidad de intermediación: 0.011140276308609393
# Nodo: 12592 - Centralidad de intermediación: 0.011135240546478539
# Nodo: 3386 - Centralidad de intermediación: 0.011122769236062762
# Nodo: 430 - Centralidad de intermediación: 0.011119166943700217
# Nodo: 9960 - Centralidad de intermediación: 0.01111666533959854
# Nodo: 9898 - Centralidad de intermediación: 0.011113585076457209
# Nodo: 1285 - Centralidad de intermediación: 0.01110765708771364
# Nodo: 12655 - Centralidad de intermediación: 0.011105200611185922
# Nodo: 10033 - Centralidad de intermediación: 0.011104177541533485
# Nodo: 11774 - Centralidad de intermediación: 0.011076545430886547
# Nodo: 10844 - Centralidad de intermediación: 0.011069646657381032
# Nodo: 12356 - Centralidad de intermediación: 0.011069166839792356
# Nodo: 5871 - Centralidad de intermediación: 0.011067631871131174
# Nodo: 9599 - Centralidad de intermediación: 0.011049364100373122
# Nodo: 9590 - Centralidad de intermediación: 0.011042438112550247
# Nodo: 9835 - Centralidad de intermediación: 0.011021337179056913
# Nodo: 12766 - Centralidad de intermediación: 0.011016620150029414
# Nodo: 8444 - Centralidad de intermediación: 0.011016513847040573
# Nodo: 12354 - Centralidad de intermediación: 0.011015808431630768
# Nodo: 9284 - Centralidad de intermediación: 0.010994411628834015
# Nodo: 10474 - Centralidad de intermediación: 0.010991871498312926
# Nodo: 573 - Centralidad de intermediación: 0.010984523684921506
# Nodo: 1782 - Centralidad de intermediación: 0.010979920860059184
# Nodo: 1778 - Centralidad de intermediación: 0.010979808078608624
# Nodo: 8772 - Centralidad de intermediación: 0.010953918592694272
# Nodo: 8470 - Centralidad de intermediación: 0.010935069930631793
# Nodo: 4270 - Centralidad de intermediación: 0.01092876057151835
# Nodo: 2319 - Centralidad de intermediación: 0.010921984337148824

# %%
import matplotlib.pyplot as plt

# Calcular la distribución de grado de la red
degree_sequence = [d for n, d in GBerlin.degree()]
degree_count = nx.degree_histogram(GBerlin)

# Graficar la distribución de grado
plt.plot(degree_count, 'b-', marker='o')
plt.title("Distribución de grado")
plt.xlabel("Grado")
plt.ylabel("Número de nodos")
plt.show()

# %%
#metodo para crear el grafo
list_Int_nodeBerlin = dfBerlin['init_node'][0:10].tolist() #lista de nodos iniciales 
list_Ter_nodeBerlin = dfBerlin['term_node'][0:10].tolist() #lista de nodos finales
list_weigthBerlin=dfBerlin['length'][0:10].tolist() #lista de pesos de los arcos 
#los pesos sirven para calcular el coste de los arcos osea el coste de pasar de un nodo a otro para asi poder calcular el coste total de una ruta

list_edgeBerlin=[] #lista de arcos 
for i in range(len(list_Int_nodeBerlin)): #recorremos la lista de nodos iniciales
  varBerlin=(list_Int_nodeBerlin[i],list_Ter_nodeBerlin[i]) #creamos una tupla con los nodos iniciales y finales
  list_edgeBerlin.append(varBerlin) #añadimos la tupla a la lista de arcos 


GBerlin = nx.DiGraph() #creamos el grafo 
GBerlin.add_nodes_from(list_Int_nodeBerlin) #añadimos los nodos iniciales al grafo
for i in range(len(list_weigthBerlin)): #recorremos la lista de pesos de los arcos 
  GBerlin.add_edges_from(list_edgeBerlin, weigth=list_weigthBerlin[i]) #añadimos los arcos al grafo 

nx.draw(GBerlin, with_labels=True) #dibujamos el grafo

# %%
#metodo para calcular el coste total de una ruta
posBerlin = nx.spring_layout(GBerlin)#posicionamiento del grafo 
weight_labelsBerlin = nx.get_edge_attributes(GBerlin,'weight')#obtenemos los pesos de los arcos para poder mostrarlos y asi poder calcular el coste total de una ruta
nx.draw_networkx(GBerlin, posBerlin, with_labels=True, font_weight='bold')#dibujamos el grafo para poder verlo
labelsBerlin = nx.get_edge_attributes(GBerlin, 'weight')#obtenemos los pesos de los arcos para poder mostrarlos en el grafo dibujado 
nx.draw_networkx_edge_labels(GBerlin, posBerlin, edge_labels=labelsBerlin)#dibujamos los pesos de los arcos en el grafo dibujado
nx.draw_networkx_edge_labels(GBerlin, posBerlin,edge_labels=weight_labelsBerlin)#dibujamos los pesos de los arcos en el grafo dibujado
# Out:
# {}

# %% [markdown]
# # **Tercera ciudad: Austin**

# %%
dfAustin = pd.read_excel('Austin_net.xlsx', sheet_name='Austin_net')
dfAustin.head()
# Out:
#    init_node  term_node  capacity        length  free_flow_time     b  power  \
# 0          1          2     99999  1.794821e+06          4296.0  0.83    5.5
# 1          2          1     99999  1.794821e+06          4296.0  0.83    5.5
# 2          2         43      1201  1.209335e+06       2074286.0  0.83    5.5
# 3          3          4     99999  7.231720e-01          1728.0  0.83    5.5
# 4          3       6572     99999  1.589523e+06          3816.0  0.83    5.5
#
#    speed  toll  link_type  ;
# 0      0     0          1  ;
# 1      0     0          1  ;
# 2      0     0          1  ;
# 3      0     0          1  ;
# 4      0     0          1  ;

# %%
# Método para crear el grafo
list_Int_nodeAustin = dfAustin['init_node'].tolist() #lista de nodos iniciales 
list_Ter_nodeAustin = dfAustin['term_node'].tolist() #lista de nodos finales
list_weigthAustin=dfAustin['length'].tolist() #lista de pesos de los arcos 
#los pesos sirven para calcular el coste de los arcos osea el coste de pasar de un nodo a otro para asi poder calcular el coste total de una ruta

list_edgeAustin=[] #lista de arcos 
for i in range(len(list_Int_nodeAustin)): #recorremos la lista de nodos iniciales
  varAustin=(list_Int_nodeAustin[i],list_Ter_nodeAustin[i]) #creamos una tupla con los nodos iniciales y finales
  list_edgeAustin.append(varAustin) #añadimos la tupla a la lista de arcos 


GAustin = nx.DiGraph() #creamos el grafo 
GAustin.add_nodes_from(list_Int_nodeAustin) #añadimos los nodos iniciales al grafo
for i in range(len(list_weigthAustin)): #recorremos la lista de pesos de los arcos 
  GAustin.add_edges_from(list_edgeAustin, weight=list_weigthAustin[i]) #añadimos los arcos al grafo 

nx.draw(GAustin, with_labels=True) #dibujamos el grafo

# %%
# Calcular la centralidad de intermediación de cada nodo
betweenness_dict = nx.betweenness_centrality(GAustin)

# Ordenar los nodos por su centralidad de intermediación
sorted_nodes = sorted(betweenness_dict.items(), key=lambda x: x[1], reverse=True)

# Mostrar los 10 nodos con mayor centralidad de intermediación
for node in sorted_nodes[:10]:
    print("Nodo:", node[0], "- Centralidad de intermediación:", node[1])
# Out:
# Nodo: 7079 - Centralidad de intermediación: 0.11828153733407606
# Nodo: 6791 - Centralidad de intermediación: 0.11760250682406226
# Nodo: 1974 - Centralidad de intermediación: 0.11571289329455002
# Nodo: 7077 - Centralidad de intermediación: 0.10815750342856965
# Nodo: 5802 - Centralidad de intermediación: 0.10527200375633422
# Nodo: 6793 - Centralidad de intermediación: 0.1045069669333418
# Nodo: 6792 - Centralidad de intermediación: 0.10436360347483843
# Nodo: 48 - Centralidad de intermediación: 0.09689786770852919
# Nodo: 49 - Centralidad de intermediación: 0.09412421257489359
# Nodo: 5790 - Centralidad de intermediación: 0.09070102042232867

# %%
import matplotlib.pyplot as plt

# Calcular la distribución de grado de la red
degree_sequence = [d for n, d in GAustin.degree()]
degree_count = nx.degree_histogram(GAustin)

# Graficar la distribución de grado
plt.plot(degree_count, 'b-', marker='o')
plt.title("Distribución de grado")
plt.xlabel("Grado")
plt.ylabel("Número de nodos")
plt.show()

# %%
# Método para crear el grafo
list_Int_nodeAustin = dfAustin['init_node'][0:10].tolist() # Lista de nodos iniciales
list_Ter_nodeAustin = dfAustin['term_node'][0:10].tolist() # Lista de nodos finales
list_weigthAustin = dfAustin['length'][0:10].tolist() # Lista de pesos de los arcos

# Los pesos sirven para calcular el coste de los arcos, es decir, el coste de pasar de un nodo a otro, para poder calcular el coste total de una ruta

list_edgeAustin = [] # Lista de arcos

for i in range(len(list_Int_nodeAustin)): # Recorremos la lista de nodos iniciales
    varAustin = (list_Int_nodeAustin[i], list_Ter_nodeAustin[i]) # Creamos una tupla con los nodos iniciales y finales
    list_edgeAustin.append(varAustin) # Añadimos la tupla a la lista de arcos

GAustin = nx.DiGraph() # Creamos el grafo
GAustin.add_nodes_from(list_Int_nodeAustin) # Añadimos los nodos iniciales al grafo

for i in range(len(list_weigthAustin)): # Recorremos la lista de pesos de los arcos
    GAustin.add_edges_from(list_edgeAustin, weight=list_weigthAustin[i]) # Añadimos los arcos al grafo

nx.draw(GAustin, with_labels=True) # Dibujamos el grafo

# %%
# Método para calcular el coste total de una ruta
posAustin = nx.spring_layout(GAustin)  # Posicionamiento del grafo
weight_labelsAustin = nx.get_edge_attributes(GAustin, 'weight')  # Obtenemos los pesos de los arcos para poder mostrarlos y calcular el coste total de una ruta
nx.draw_networkx(GAustin, posAustin, with_labels=True, font_weight='bold')  # Dibujamos el grafo para visualizarlo
labelsAustin = nx.get_edge_attributes(GAustin, 'weight')  # Obtenemos los pesos de los arcos para mostrarlos en el grafo dibujado
nx.draw_networkx_edge_labels(GAustin, posAustin, edge_labels=labelsAustin)  # Dibujamos los pesos de los arcos en el grafo dibujado
nx.draw_networkx_edge_labels(GAustin, posAustin, edge_labels=weight_labelsAustin)  # Dibujamos los pesos de los arcos en el grafo dibujado
# Out:
# {(1, 2): Text(-0.34947103401675006, 0.0762602104800372, '0.223346'),
#  (2, 1): Text(-0.34947103401675006, 0.0762602104800372, '0.223346'),
#  (2, 43): Text(-0.52772741730803, -0.21642889104656154, '0.223346'),
#  (3, 4): Text(0.6493712278260447, 0.07667152234133807, '0.223346'),
#  (3, 6572): Text(0.7361055878509231, 0.33134297138623753, '0.223346'),
#  (4, 3): Text(0.6493712278260447, 0.07667152234133807, '0.223346'),
#  (4, 4520): Text(0.6160454660808612, -0.34807709363000466, '0.223346'),
#  (4, 6572): Text(0.7247947764846747, 0.1958316160854276, '0.223346'),
#  (5, 6): Text(-0.3469397242475656, -0.3784129123409525, '0.223346'),
#  (5, 1974): Text(-0.5684169284350424, 0.5423669059591546, '0.223346')}

# %% [markdown]
# # **RESPUESTAS**

# %% [markdown]
# Considerando las diferentes redes de transporte de las ciudades de Chicago, Berlín y Austin, realizaremos un análisis sobre el comportamiento del flujo de tráfico en cada una de ellas. Para este análisis, exploraremos los siguientes aspectos:
#
# 1. Identificación de los nodos más importantes en la red: Los nodos más relevantes en la red son aquellos que poseen un mayor peso en comparación con el resto. Estos nodos tienen más conexiones con otros nodos, lo que los convierte en puntos clave para el flujo de tráfico. Al analizar los primeros 25 nodos o más, es posible identificar los nodos más influyentes en cada ciudad. En el caso de Chicago, puede requerir mostrar más nodos para visualizar conexiones significativas.
#
# 2. Distribución de la centralidad de la red: En las redes de transporte de Chicago, Berlín y Austin, se observa una distribución descentralizada de la centralidad. Esto significa que no hay un nodo central dominante al que todos los demás nodos estén directamente conectados. En cambio, estos sistemas se caracterizan por una descentralización, lo que permite la existencia de múltiples caminos y rutas alternativas para la comunicación entre nodos.
#
# 3. Robustez de la red: Las redes de transporte en estas ciudades se consideran robustas debido a su diseño descentralizado. Incluso si un nodo desaparece o falla, el sistema sigue siendo efectivo ya que existe la posibilidad de conexión entre los nodos a través de rutas alternativas. Esto garantiza que el sistema continúe cumpliendo su función principal, incluso en situaciones de fallos o interrupciones.
#
# 4. Comportamiento ante fallos aleatorios y dirigidos: En caso de fallos aleatorios en las redes de transporte de estas ciudades, la robustez del sistema permite que siga funcionando sin resultados negativos significativos. Sin embargo, si se produce una falla dirigida hacia un nodo específico, puede haber una interrupción más significativa en el flujo de tráfico hacia ese destino en particular. A pesar de esto, la estructura descentralizada del sistema ayuda a mitigar el impacto y a mantener la funcionalidad general del sistema.
#
# 5. Comparación entre las tres ciudades: Al comparar los resultados de las pruebas realizadas en este análisis, se pueden observar diferencias entre las ciudades de Chicago, Berlin y Austin. En Chicago y Berlín, incluso al mostrar pocos nodos, se puede apreciar rápidamente la existencia de conexiones entre ellos. Por otro lado, en Chicago, es necesario mostrar un mayor número de nodos para empezar a visualizar conexiones entre más de dos nodos y no solo hacia el exterior del grafo. Sin embargo, al imprimir el sistema completo o la gran mayoría de los datos, Chicago se asemeja más a austin, mientras que Berlín tiende a tener nodos más separados y una mayor concentración en la parte central del grafo.
#
# 6. Explicación de la autoorganización de los escenarios seleccionados: Al imprimir nodos aleatorios, se puede observar cómo el sistema intenta organizarse de manera que se mantenga la interconexión característica de un sistema descentralizado. A medida que se añaden más nodos, el sistema adquiere la forma completa con todos los nodos, lo cual permite que se cumpla su función sin fallos y mantenga la conectividad deseada en cada ciudad.
